# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [3,5,7,8]

plt.plot(x,y)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("simple line grapg")

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
